# %%
# Copyright (c) Microsoft. All rights reserved.

import types
from enum import Enum
from typing import Any, Union, get_args, get_origin, get_type_hints

# %pip install semantic_kernel

from semantic_kernel.const import PARSED_ANNOTATION_UNION_DELIMITER
from semantic_kernel.exceptions.function_exceptions import FunctionInvalidParameterConfiguration
from semantic_kernel.kernel_pydantic import KernelBaseModel

TYPE_MAPPING = {
    int: "integer",
    str: "string",
    bool: "boolean",
    float: "number",
    list: "array",
    dict: "object",
    set: "array",
    tuple: "array",
    "int": "integer",
    "str": "string",
    "bool": "boolean",
    "float": "number",
    "list": "array",
    "dict": "object",
    "set": "array",
    "tuple": "array",
    "object": "object",
    "array": "array",
}


class KernelJsonSchemaBuilder:
    """Kernel JSON schema builder."""

    @classmethod
    def build(cls, parameter_type: type | str, description: str | None = None) -> dict[str, Any]:
        """Builds the JSON schema for a given parameter type and description.

        Args:
            parameter_type (type | str): The parameter type.
            description (str, optional): The description of the parameter. Defaults to None.

        Returns:
            dict[str, Any]: The JSON schema for the parameter type.
        """
        if isinstance(parameter_type, str):
            return cls.build_from_type_name(parameter_type, description)
        if isinstance(parameter_type, KernelBaseModel):
            return cls.build_model_schema(parameter_type, description)
        if isinstance(parameter_type, type) and issubclass(parameter_type, Enum):
            return cls.build_enum_schema(parameter_type, description)
        if hasattr(parameter_type, "__annotations__"):
            return cls.build_model_schema(parameter_type, description)
        if hasattr(parameter_type, "__args__"):
            return cls.handle_complex_type(parameter_type, description)
        schema = cls.get_json_schema(parameter_type)
        if description:
            schema["description"] = description
        return schema

    @classmethod
    def build_model_schema(cls, model: type, description: str | None = None) -> dict[str, Any]:
        """Builds the JSON schema for a given model and description.

        Args:
            model (type): The model type.
            description (str, optional): The description of the model. Defaults to None.

        Returns:
            dict[str, Any]: The JSON schema for the model.
        """
        # TODO (moonbox3): add support for handling forward references, which is not currently tested
        # https://github.com/microsoft/semantic-kernel/issues/6464
        properties = {}
        required = []
        hints = get_type_hints(model, globals(), locals())

        for field_name, field_type in hints.items():
            field_description = None
            if hasattr(model, "model_fields") and field_name in model.model_fields:
                field_info = model.model_fields[field_name]
                if isinstance(field_info.metadata, dict):
                    field_description = field_info.metadata.get("description")
                elif isinstance(field_info.metadata, list) and field_info.metadata:
                    field_description = field_info.metadata[0]
                elif hasattr(field_info, "description"):
                    field_description = field_info.description
            if not cls._is_optional(field_type):
                required.append(field_name)
            properties[field_name] = cls.build(field_type, field_description)

        schema = {"type": "object", "properties": properties}
        if required:
            schema["required"] = required
        if description:
            schema["description"] = description

        return schema

    @classmethod
    def _is_optional(cls, field_type: Any) -> bool:
        return get_origin(field_type) in {types.UnionType, Union} and type(None) in get_args(field_type)

    @classmethod
    def build_from_type_name(cls, parameter_type: str, description: str | None = None) -> dict[str, Any]:
        """Builds the JSON schema for a given parameter type name and description.

        Args:
            parameter_type (str): The parameter type name.
            description (str, optional): The description of the parameter. Defaults to None.

        Returns:
            dict[str, Any]: The JSON schema for the parameter type.
        """
        schema: dict[str, Any] = {}
        if PARSED_ANNOTATION_UNION_DELIMITER in parameter_type:
            # this means it is a Union or | so need to build with "anyOf"
            types = parameter_type.split(PARSED_ANNOTATION_UNION_DELIMITER)
            schemas = [cls.build_from_type_name(t.strip(), description) for t in types]
            schema["anyOf"] = schemas
        else:
            type_name = TYPE_MAPPING.get(parameter_type, "object")
            schema["type"] = type_name
            if description:
                schema["description"] = description
        return schema

    @classmethod
    def get_json_schema(cls, parameter_type: type) -> dict[str, Any]:
        """Gets JSON schema for a given parameter type.

        Args:
            parameter_type (type): The parameter type.

        Returns:
            dict[str, Any]: The JSON schema for the parameter type.
        """
        type_name = TYPE_MAPPING.get(parameter_type, "object")
        return {"type": type_name}

    @classmethod
    def handle_complex_type(cls, parameter_type: type, description: str | None = None) -> dict[str, Any]:
        """Handles building the JSON schema for complex types.

        Args:
            parameter_type (type): The parameter type.
            description (str, optional): The description of the parameter. Defaults to None.

        Returns:
            dict[str, Any]: The JSON schema for the parameter type.
        """
        origin = get_origin(parameter_type)
        args = get_args(parameter_type)

        schema: dict[str, Any] = {}
        if origin is list or origin is set:
            item_type = args[0]
            schema = {"type": "array", "items": cls.build(item_type)}
            if description:
                schema["description"] = description
            return schema
        if origin is dict:
            _, value_type = args
            additional_properties = cls.build(value_type)
            if additional_properties == {"type": "object"}:
                additional_properties["properties"] = {}  # Account for differences in Python 3.10 dict
            schema = {"type": "object", "additionalProperties": additional_properties}
            if description:
                schema["description"] = description
            return schema
        if origin is tuple:
            items = [cls.build(arg) for arg in args]
            schema = {"type": "array", "items": items}
            if description:
                schema["description"] = description
            return schema
        if origin in {Union, types.UnionType}:
            # Handle Optional[T] (Union[T, None]) by making schema nullable
            if len(args) == 2 and type(None) in args:
                non_none_type = args[0] if args[1] is type(None) else args[1]
                schema = cls.build(non_none_type)
                schema["type"] = [schema["type"], "null"]
                if description:
                    schema["description"] = description
                return schema
            schemas = [cls.build(arg, description) for arg in args]
            return {"anyOf": schemas}
        schema = cls.get_json_schema(parameter_type)
        if description:
            schema["description"] = description
        return schema

    @classmethod
    def build_enum_schema(cls, enum_type: type, description: str | None = None) -> dict[str, Any]:
        """Builds the JSON schema for an enum type.

        Args:
            enum_type (type): The enum type.
            description (str, optional): The description of the enum. Defaults to None.

        Returns:
            dict[str, Any]: The JSON schema for the enum type.
        """
        if not issubclass(enum_type, Enum):
            raise FunctionInvalidParameterConfiguration(f"{enum_type} is not a valid Enum type")

        try:
            enum_values = [item.value for item in enum_type]
        except TypeError as ex:
            raise FunctionInvalidParameterConfiguration(f"Failed to get enum values for {enum_type}") from ex
        schema = {"type": TYPE_MAPPING.get(type(enum_values[0]), "string"), "enum": enum_values}
        if description:
            schema["description"] = description
        return schema
# Out:
# Requirement already satisfied: semantic_kernel in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.5.1)
# Requirement already satisfied: aiohttp<4.0,>=3.8 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (3.10.4)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (0.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (3.1.4)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (1.6.0)
# Requirement already satisfied: numpy>=1.25 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (2.0.1)
# Requirement already satisfied: openai>=1.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (1.41.0)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (0.19.3)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.24.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (1.26.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.24.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (1.26.0)
# Requirement already satisfied: pandas<3.0.0,>=2.2.2 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (2.2.2)
# Requirement already satisfied: prance<24.0.0.0,>=23.6.21.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (23.6.21.0)
# Requirement already satisfied: pybars4<0.10.0,>=0.9.13 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (0.9.13)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (2.8.2)
# Requirement already satisfied: pydantic-settings<3,>=2 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (2.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0,>=3.8->semantic_kernel) (2.3.7)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0,>=3.8->semantic_kernel) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0,>=3.8->semantic_kernel) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0,>=3.8->semantic_kernel) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0,>=3.8->semantic_kernel) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0,>=3.8->semantic_kernel) (1.9.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2<4.0.0,>=3.1.3->semantic_kernel) (2.1.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (0.5.0)
# Requirement already satisfied: sniffio in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (4.12.2)
# Requirement already satisfied: isodate in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (0.6.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (4.23.0)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (0.3.3)
# Requirement already satisfied: more-itertools in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (10.4.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (0.6.2)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (0.7.1)
# Requirement already satisfied: parse in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (1.20.2)
# Requirement already satisfied: werkzeug in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (3.0.3)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-api<2.0.0,>=1.24.0->semantic_kernel) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.0.0,>=6.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-api<2.0.0,>=1.24.0->semantic_kernel) (8.0.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-sdk<2.0.0,>=1.24.0->semantic_kernel) (0.47b0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3.0.0,>=2.2.2->semantic_kernel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3.0.0,>=2.2.2->semantic_kernel) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3.0.0,>=2.2.2->semantic_kernel) (2024.1)
# Requirement already satisfied: chardet>=3.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (0.18.6)
# Requirement already satisfied: requests>=2.25 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (2.32.3)
# Requirement already satisfied: six~=1.15 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (24.1)
# Requirement already satisfied: PyMeta3>=0.5.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pybars4<0.10.0,>=0.9.13->semantic_kernel) (0.5.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=2->semantic_kernel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=2->semantic_kernel) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic-settings<3,>=2->semantic_kernel) (1.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio<5,>=3.5.0->openai>=1.0->semantic_kernel) (3.7)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.24.0->semantic_kernel) (1.16.0)
# Requirement already satisfied: certifi in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic_kernel) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic_kernel) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0->semantic_kernel) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api<2.0.0,>=1.24.0->semantic_kernel) (3.20.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic_kernel) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic_kernel) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic_kernel) (0.20.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic_kernel) (6.0.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic_kernel) (0.4.3)
# Requirement already satisfied: rfc3339-validator in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic_kernel) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic_kernel) (1.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (2.2.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ruamel.yaml>=0.17.10->prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (0.2.8)
# Requirement already satisfied: colorama in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>4->openai>=1.0->semantic_kernel) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
{
}
# Out:
# {}

# %%
# %pip install semantic_kernel
# Out:
# Requirement already satisfied: semantic_kernel in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.5.1)
# Requirement already satisfied: aiohttp<4.0,>=3.8 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (3.10.4)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (0.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (3.1.4)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (1.6.0)
# Requirement already satisfied: numpy>=1.25 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (2.0.1)
# Requirement already satisfied: openai>=1.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (1.41.0)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (0.19.3)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.24.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (1.26.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.24.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (1.26.0)
# Requirement already satisfied: pandas<3.0.0,>=2.2.2 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (2.2.2)
# Requirement already satisfied: prance<24.0.0.0,>=23.6.21.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (23.6.21.0)
# Requirement already satisfied: pybars4<0.10.0,>=0.9.13 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (0.9.13)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (2.8.2)
# Requirement already satisfied: pydantic-settings<3,>=2 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from semantic_kernel) (2.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0,>=3.8->semantic_kernel) (2.3.7)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0,>=3.8->semantic_kernel) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0,>=3.8->semantic_kernel) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0,>=3.8->semantic_kernel) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0,>=3.8->semantic_kernel) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0,>=3.8->semantic_kernel) (1.9.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2<4.0.0,>=3.1.3->semantic_kernel) (2.1.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (0.5.0)
# Requirement already satisfied: sniffio in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.0->semantic_kernel) (4.12.2)
# Requirement already satisfied: isodate in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (0.6.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (4.23.0)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (0.3.3)
# Requirement already satisfied: more-itertools in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (10.4.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (0.6.2)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (0.7.1)
# Requirement already satisfied: parse in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (1.20.2)
# Requirement already satisfied: werkzeug in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (3.0.3)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-api<2.0.0,>=1.24.0->semantic_kernel) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.0.0,>=6.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-api<2.0.0,>=1.24.0->semantic_kernel) (8.0.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-sdk<2.0.0,>=1.24.0->semantic_kernel) (0.47b0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3.0.0,>=2.2.2->semantic_kernel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3.0.0,>=2.2.2->semantic_kernel) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3.0.0,>=2.2.2->semantic_kernel) (2024.1)
# Requirement already satisfied: chardet>=3.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (0.18.6)
# Requirement already satisfied: requests>=2.25 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (2.32.3)
# Requirement already satisfied: six~=1.15 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (24.1)
# Requirement already satisfied: PyMeta3>=0.5.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pybars4<0.10.0,>=0.9.13->semantic_kernel) (0.5.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=2->semantic_kernel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=2->semantic_kernel) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic-settings<3,>=2->semantic_kernel) (1.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio<5,>=3.5.0->openai>=1.0->semantic_kernel) (3.7)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.24.0->semantic_kernel) (1.16.0)
# Requirement already satisfied: certifi in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic_kernel) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic_kernel) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0->semantic_kernel) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api<2.0.0,>=1.24.0->semantic_kernel) (3.20.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic_kernel) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic_kernel) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic_kernel) (0.20.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic_kernel) (6.0.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic_kernel) (0.4.3)
# Requirement already satisfied: rfc3339-validator in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic_kernel) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic_kernel) (1.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (2.2.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ruamel.yaml>=0.17.10->prance<24.0.0.0,>=23.6.21.0->semantic_kernel) (0.2.8)
# Requirement already satisfied: colorama in c:\users\bryan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>4->openai>=1.0->semantic_kernel) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
""" Snippet Generated Select with current selected text """
SELECT * 
FROM { ;} 
""" End of the Snippet Generated Select """


	"name": "SyntaxError",
	"message": "unterminated string literal (detected at line 4) (<ipython-input-2-b936090a3039>, line 4)",
	
    
    """ Snippet Generated Select with current selected text """
    SELECT * 
    "stack": "  Cell In[2], line 4 ;"
    """ End of the Snippet Generated Select """


""" Snippet Generated Select with current selected text """
SELECT * 
FROM      ; 
""" End of the Snippet Generated Select """


    
    "stack": "---------------------------------------------------------------------------
             ^
SyntaxError: unterminated string literal (detected at line 4)
""
# Out:
#   File <tokenize>:11
#     """ Snippet Generated Select with current selected text """
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
	
    
    # Snippet Generated Select with current selected text
    # SELECT * 
    # FROM "name": "SyntaxError"
    # End of the Snippet Generated Select

# %%
{
	"name": "SyntaxError",
	"message": "unterminated string literal (detected at line 4) (<ipython-input-4-fda4dc235450>, line 4)",
	"stack": "  Cell In[4], line 4
    \"stack\": \"  Cell In[3], line 4
             ^
SyntaxError: unterminated string literal (detected at line 4)
"
}
# Out:
#   Cell In[5], line 4
#     "stack": "  Cell In[4], line 4
#              ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
{
	"name": "SyntaxError",
	"message": "unterminated string literal (detected at line 4) (<ipython-input-5-a55fa39a72b7>, line 4)",
	"stack": "  Cell In[5], line 4
    \"stack\": \"  Cell In[4], line 4
             ^
SyntaxError: unterminated string literal (detected at line 4)
"
}

# %%
    def generate_new_function():
        # Your code here
        pass

# %%
{
	"name": "IndentationError",
	"message": "expected an indented block after function definition on line 1 (1461661914.py, line 2)",
    "stack": "  Cell In[144], line 2\n    {% load \"\"\" Snippet Generated Select with current selected text \"\"\"_tags %}\n    ^\nIndentationError: expected an indented block after function definition on line 1\n"
}
# Out:
# {'name': 'IndentationError',
#  'message': 'expected an indented block after function definition on line 1 (1461661914.py, line 2)',
#  'stack': '  Cell In[144], line 2\n    {% load """ Snippet Generated Select with current selected text """_tags %}\n    ^\nIndentationError: expected an indented block after function definition on line 1\n'}

# %%
{
    "name": "SyntaxError",
    "message": "unterminated string literal (detected at line 4) (1930594662.py, line 4)",
    "stack": "  Cell In[160], line 4\n    \"stack\": \"  Cell In[144], line 2\n             ^\nSyntaxError: unterminated string literal (detected at line 4)\n"
}

# %%
def example_function():
    # Your indented code here
    print("This is an example function.")

# %%
def my_function():
    print("Hello, World!")

# %%
def my_function():
print("Hello, World!")
# Out:
#   Cell In[234], line 2
#     print("Hello, World!")
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# To fix the IndentationError, you need to add an indented block after the function definition.
#
# Made changes.
